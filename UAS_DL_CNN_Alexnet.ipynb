# %% [markdown]
# <a href="https://colab.research.google.com/github/bagudzz/uas_CNN_Alexnet_C/blob/main/UAS_DL_CNN_Alexnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UAS Deepl Learning, CNN using Alexnet
# Bagus kustiono.O / 202211420017

# %%
# !pip -q install gradio
# !pip -q install torch torchvision
